# %% [markdown]
# <a href="https://colab.research.google.com/github/gap1070/CS-417--Participation/blob/main/API_Participation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = "https://api.open-meteo.com/v1/forecast"
params = {
    "latitude": 43.05,
    "longitude": -76.15,
    "current_weather": True
}

response = requests.get(url, params=params)
data = response.json()
print(data["current_weather"]["temperature"])

locations = [
    {"name": "Syracuse, NY", "latitude": 43.05, "longitude": -76.15},
    {"name": "New York City, NY", "latitude": 43.05, "longitude": -76.15},
    {"name": "Syracuse, NY", "latitude": 43.05, "longitude": -76.15},
]
# Out:
# -1.7
